# %%
import pandas as pd

data = pd.read_json("data/exports/image_label-v0.1.json")

# %%
data_label = data["label"]
data_label.head(5)
# Out:
# 0        sarcasm
# 1        sarcasm
# 2        sarcasm
# 3    not-sarcasm
# 4    not-sarcasm
# Name: label, dtype: object

# %%
len_data_label = len(data_label)
len_sarcasm = len(data_label[data_label == "sarcasm"])
len_not_sarcasm = len(data_label[data_label == "not-sarcasm"])

# %%
print("Sarcasm %", len_sarcasm / len_data_label)
print("Not-Sarcasm %", len_not_sarcasm/ len_data_label)
# Out:
# Sarcasm % 0.6786978060863411
# Not-Sarcasm % 0.3213021939136589
