# %%
import pandas as pd
import numpy as np

def load_export(file_path):
    record = pd.read_csv(file_path, header=None, names=["key", "image", "label", "score"])
    return record

record = load_export("data/exports/export-0.1.csv")

# %%
record.to_json("data/exports/image_label.json", orient='records')
